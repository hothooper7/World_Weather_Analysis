# %%
# Import dependencies
from citipy import citipy
import pandas as pd
import numpy as np
import json 
import requests
import timeit

from datetime import datetime
from config import weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 748

# %%
# Perform an API call with the OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Retrieve Lat, Lon, Max Temp, Percent Humidity, Percent Cloudiness, Wind Speed, Weather Description
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | padang
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 1 | port blair
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | port elizabeth
# Processing Record 7 of Set 1 | kapaa
# Processing Record 8 of Set 1 | laguna
# Processing Record 9 of Set 1 | saint-paul
# Processing Record 10 of Set 1 | san cristobal
# Processing Record 11 of Set 1 | cidreira
# Processing Record 12 of Set 1 | puerto ayora
# Processing Record 13 of Set 1 | carnarvon
# Processing Record 14 of Set 1 | bilibino
# Processing Record 15 of Set 1 | cape town
# Processing Record 16 of Set 1 | port alfred
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | batagay-alyta
# Processing Record 19 of Set 1 | upernavik
# Processing Record 20 of Set 1 | general pico
# Processing Record 21 of Set 1 | kurchum
# Processing Record 22 of Set 1 | kaitangata
# Processing Record 23 of Set 1 | bredasdorp
# Processing Record 24 of Set 1 | nuuk
# Processing Record 25 of Set 1 | gejiu
# Processing Record 26 of Set 1 | norman wells
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 1 | bilma
# Processing Record 30 of Set 1 | tuktoyaktuk
# Processing Record 31 of Set 1 | pipar
# Processing Record 32 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 1 | ribeira grande
# Processing Record 34 of Set 1 | picton
# Processing Record 35 of Set 1 | khatanga
# Processing Record 36 of Set 1 | maroantsetra
# Processing Record 37 of Set 1 | balabac
# Processing Record 38 of Set 1 | albany
# Processing Record 39 of Set 1 | provideniya
# Processing Record 40 of Set 1 | namibe
# Processing Record 41 of Set 1 | tampakan
# Processing Record 42 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 1 | bluff
# Processing Record 44 of Set 1 | busselton
# Processing Record 45 of Set 1 | dikson
# Processing Record 46 of Set 1 | hofn
# Processing Record 47 of Set 1 | leninskoye
# Processing Record 48 of Set 1 | alta floresta
# Processing Record 49 of Set 1 | sioux lookout
# Processing Record 50 of Set 1 | butaritari
# Processing Record 1 of Set 2 | praya
# Processing Record 2 of Set 2 | yulara
# Processing Record 3 of Set 2 | bridlington
# Processing Record 4 of Set 2 | lavrentiya
# Processing Record 5 of Set 2 | buariki
# City not found. Skipping...
# Processing Record 6 of Set 2 | kuito
# Processing Record 7 of Set 2 | one hundred mile house
# City not found. Skipping...
# Processing Record 8 of Set 2 | hermanus
# Processing Record 9 of Set 2 | chapais
# Processing Record 10 of Set 2 | bambous virieux
# Processing Record 11 of Set 2 | yellowknife
# Processing Record 12 of Set 2 | challapata
# Processing Record 13 of Set 2 | beloha
# Processing Record 14 of Set 2 | roald
# Processing Record 15 of Set 2 | innisfail
# Processing Record 16 of Set 2 | yerbogachen
# Processing Record 17 of Set 2 | ponca city
# Processing Record 18 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 2 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 20 of Set 2 | aklavik
# Processing Record 21 of Set 2 | avarua
# Processing Record 22 of Set 2 | floro
# Processing Record 23 of Set 2 | chuy
# Processing Record 24 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 2 | hobart
# Processing Record 26 of Set 2 | turukhansk
# Processing Record 27 of Set 2 | mandalgovi
# Processing Record 28 of Set 2 | pisco
# Processing Record 29 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of Set 2 | mitsamiouli
# Processing Record 32 of Set 2 | luderitz
# Processing Record 33 of Set 2 | qaanaaq
# Processing Record 34 of Set 2 | saint-philippe
# Processing Record 35 of Set 2 | babanusah
# City not found. Skipping...
# Processing Record 36 of Set 2 | coquimbo
# Processing Record 37 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 2 | makakilo city
# Processing Record 39 of Set 2 | san quintin
# Processing Record 40 of Set 2 | belomorsk
# Processing Record 41 of Set 2 | hithadhoo
# Processing Record 42 of Set 2 | bartica
# Processing Record 43 of Set 2 | airai
# Processing Record 44 of Set 2 | vaini
# Processing Record 45 of Set 2 | jamestown
# Processing Record 46 of Set 2 | ponta do sol
# Processing Record 47 of Set 2 | ostrovnoy
# Processing Record 48 of Set 2 | naryan-mar
# Processing Record 49 of Set 2 | east london
# Processing Record 50 of Set 2 | moen
# Processing Record 1 of Set 3 | ixtapa
# Processing Record 2 of Set 3 | marzuq
# Processing Record 3 of Set 3 | padrauna
# Processing Record 4 of Set 3 | samarai
# Processing Record 5 of Set 3 | tuatapere
# Processing Record 6 of Set 3 | inhambane
# Processing Record 7 of Set 3 | rawson
# Processing Record 8 of Set 3 | hasaki
# Processing Record 9 of Set 3 | isangel
# Processing Record 10 of Set 3 | meylan
# Processing Record 11 of Set 3 | new norfolk
# Processing Record 12 of Set 3 | kruisfontein
# Processing Record 13 of Set 3 | banjar
# Processing Record 14 of Set 3 | victoria
# Processing Record 15 of Set 3 | hilo
# Processing Record 16 of Set 3 | palmer
# Processing Record 17 of Set 3 | philippeville
# Processing Record 18 of Set 3 | arlit
# Processing Record 19 of Set 3 | tiksi
# Processing Record 20 of Set 3 | paita
# Processing Record 21 of Set 3 | mount isa
# Processing Record 22 of Set 3 | inta
# Processing Record 23 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 3 | thompson
# Processing Record 25 of Set 3 | mount gambier
# Processing Record 26 of Set 3 | west bromwich
# Processing Record 27 of Set 3 | pevek
# Processing Record 28 of Set 3 | folkestone
# Processing Record 29 of Set 3 | naze
# Processing Record 30 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 3 | vestmanna
# Processing Record 32 of Set 3 | mutsu
# Processing Record 33 of Set 3 | abu kamal
# Processing Record 34 of Set 3 | kandrian
# Processing Record 35 of Set 3 | hambantota
# Processing Record 36 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 37 of Set 3 | severodvinsk
# Processing Record 38 of Set 3 | benjamin constant
# Processing Record 39 of Set 3 | torit
# Processing Record 40 of Set 3 | loandjili
# Processing Record 41 of Set 3 | vardo
# Processing Record 42 of Set 3 | goba
# Processing Record 43 of Set 3 | xining
# Processing Record 44 of Set 3 | comodoro rivadavia
# Processing Record 45 of Set 3 | bethel
# Processing Record 46 of Set 3 | lerwick
# Processing Record 47 of Set 3 | fukue
# Processing Record 48 of Set 3 | smithers
# Processing Record 49 of Set 3 | port lincoln
# Processing Record 50 of Set 3 | barrow
# Processing Record 1 of Set 4 | leningradskiy
# Processing Record 2 of Set 4 | karasjok
# Processing Record 3 of Set 4 | vieste
# Processing Record 4 of Set 4 | severo-kurilsk
# Processing Record 5 of Set 4 | rosarito
# Processing Record 6 of Set 4 | tucurui
# Processing Record 7 of Set 4 | zhangye
# Processing Record 8 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 9 of Set 4 | cabo san lucas
# Processing Record 10 of Set 4 | dingle
# Processing Record 11 of Set 4 | penticton
# Processing Record 12 of Set 4 | huanren
# Processing Record 13 of Set 4 | tsiroanomandidy
# Processing Record 14 of Set 4 | yinchuan
# Processing Record 15 of Set 4 | lata
# Processing Record 16 of Set 4 | byron bay
# Processing Record 17 of Set 4 | georgetown
# Processing Record 18 of Set 4 | geraldton
# Processing Record 19 of Set 4 | lompoc
# Processing Record 20 of Set 4 | det udom
# Processing Record 21 of Set 4 | faanui
# Processing Record 22 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 4 | chokurdakh
# Processing Record 24 of Set 4 | torbay
# Processing Record 25 of Set 4 | regina
# Processing Record 26 of Set 4 | morehead
# Processing Record 27 of Set 4 | katobu
# Processing Record 28 of Set 4 | husavik
# Processing Record 29 of Set 4 | barroso
# Processing Record 30 of Set 4 | axim
# Processing Record 31 of Set 4 | vila franca do campo
# Processing Record 32 of Set 4 | ulaanbaatar
# Processing Record 33 of Set 4 | nanortalik
# Processing Record 34 of Set 4 | hovd
# Processing Record 35 of Set 4 | nikolskoye
# Processing Record 36 of Set 4 | asau
# Processing Record 37 of Set 4 | daru
# Processing Record 38 of Set 4 | manzanillo
# Processing Record 39 of Set 4 | ambilobe
# Processing Record 40 of Set 4 | brandon
# Processing Record 41 of Set 4 | vikhorevka
# Processing Record 42 of Set 4 | kokopo
# Processing Record 43 of Set 4 | tuy hoa
# Processing Record 44 of Set 4 | buala
# Processing Record 45 of Set 4 | castro
# Processing Record 46 of Set 4 | bayonet point
# Processing Record 47 of Set 4 | catacocha
# Processing Record 48 of Set 4 | saskylakh
# Processing Record 49 of Set 4 | kodiak
# Processing Record 50 of Set 4 | bantry
# Processing Record 1 of Set 5 | lloydminster
# Processing Record 2 of Set 5 | esperance
# Processing Record 3 of Set 5 | altay
# Processing Record 4 of Set 5 | hecun
# Processing Record 5 of Set 5 | salalah
# Processing Record 6 of Set 5 | yushu
# Processing Record 7 of Set 5 | oranjestad
# Processing Record 8 of Set 5 | barra patuca
# Processing Record 9 of Set 5 | margate
# Processing Record 10 of Set 5 | acuna
# City not found. Skipping...
# Processing Record 11 of Set 5 | yanan
# City not found. Skipping...
# Processing Record 12 of Set 5 | maragogi
# Processing Record 13 of Set 5 | egvekinot
# Processing Record 14 of Set 5 | atuona
# Processing Record 15 of Set 5 | ejea de los caballeros
# Processing Record 16 of Set 5 | kachug
# Processing Record 17 of Set 5 | namtsy
# Processing Record 18 of Set 5 | kavieng
# Processing Record 19 of Set 5 | macusani
# Processing Record 20 of Set 5 | miramar
# Processing Record 21 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 22 of Set 5 | lagoa
# Processing Record 23 of Set 5 | navahrudak
# Processing Record 24 of Set 5 | korla
# Processing Record 25 of Set 5 | parksville
# Processing Record 26 of Set 5 | solone
# Processing Record 27 of Set 5 | pithora
# Processing Record 28 of Set 5 | touros
# Processing Record 29 of Set 5 | poplar bluff
# Processing Record 30 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 31 of Set 5 | qaqortoq
# Processing Record 32 of Set 5 | bad bevensen
# Processing Record 33 of Set 5 | vilhena
# Processing Record 34 of Set 5 | sibolga
# Processing Record 35 of Set 5 | saint andrews
# Processing Record 36 of Set 5 | kaniama
# Processing Record 37 of Set 5 | pangnirtung
# Processing Record 38 of Set 5 | bonthe
# Processing Record 39 of Set 5 | watsa
# Processing Record 40 of Set 5 | pacific grove
# Processing Record 41 of Set 5 | beidao
# Processing Record 42 of Set 5 | puerto palomas
# Processing Record 43 of Set 5 | bjelovar
# Processing Record 44 of Set 5 | matara
# Processing Record 45 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 5 | agadez
# Processing Record 47 of Set 5 | arraial do cabo
# Processing Record 48 of Set 5 | nam tha
# City not found. Skipping...
# Processing Record 49 of Set 5 | ampanihy
# Processing Record 50 of Set 5 | oistins
# Processing Record 1 of Set 6 | bengkulu
# Processing Record 2 of Set 6 | manokwari
# Processing Record 3 of Set 6 | panzhihua
# Processing Record 4 of Set 6 | asosa
# Processing Record 5 of Set 6 | malanje
# Processing Record 6 of Set 6 | bihar
# Processing Record 7 of Set 6 | havoysund
# Processing Record 8 of Set 6 | berlin
# Processing Record 9 of Set 6 | tinskoy
# Processing Record 10 of Set 6 | kerouane
# Processing Record 11 of Set 6 | conde
# Processing Record 12 of Set 6 | adre
# Processing Record 13 of Set 6 | lebu
# Processing Record 14 of Set 6 | sao jose da coroa grande
# Processing Record 15 of Set 6 | brae
# Processing Record 16 of Set 6 | solnechnyy
# Processing Record 17 of Set 6 | meulaboh
# Processing Record 18 of Set 6 | anloga
# Processing Record 19 of Set 6 | clyde river
# Processing Record 20 of Set 6 | ayan
# Processing Record 21 of Set 6 | kungurtug
# Processing Record 22 of Set 6 | kutum
# Processing Record 23 of Set 6 | macia
# Processing Record 24 of Set 6 | richards bay
# Processing Record 25 of Set 6 | nome
# Processing Record 26 of Set 6 | hongjiang
# Processing Record 27 of Set 6 | kysyl-syr
# Processing Record 28 of Set 6 | tefe
# Processing Record 29 of Set 6 | mar del plata
# Processing Record 30 of Set 6 | nishihara
# Processing Record 31 of Set 6 | changde
# Processing Record 32 of Set 6 | suoyarvi
# Processing Record 33 of Set 6 | berdigestyakh
# Processing Record 34 of Set 6 | guerrero negro
# Processing Record 35 of Set 6 | surt
# Processing Record 36 of Set 6 | antofagasta
# Processing Record 37 of Set 6 | poum
# Processing Record 38 of Set 6 | kasempa
# Processing Record 39 of Set 6 | nakamura
# Processing Record 40 of Set 6 | buraydah
# Processing Record 41 of Set 6 | diu
# Processing Record 42 of Set 6 | neyshabur
# Processing Record 43 of Set 6 | shemonaikha
# Processing Record 44 of Set 6 | tehuacan
# Processing Record 45 of Set 6 | labuhan
# Processing Record 46 of Set 6 | ovre ardal
# Processing Record 47 of Set 6 | xifeng
# Processing Record 48 of Set 6 | caravelas
# Processing Record 49 of Set 6 | lasa
# Processing Record 50 of Set 6 | mayumba
# Processing Record 1 of Set 7 | mahajanga
# Processing Record 2 of Set 7 | temaraia
# City not found. Skipping...
# Processing Record 3 of Set 7 | kloulklubed
# Processing Record 4 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 5 of Set 7 | marawi
# Processing Record 6 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 7 | mikuni
# Processing Record 8 of Set 7 | great yarmouth
# Processing Record 9 of Set 7 | taft
# Processing Record 10 of Set 7 | araouane
# Processing Record 11 of Set 7 | sorong
# Processing Record 12 of Set 7 | koksovyy
# Processing Record 13 of Set 7 | isiro
# Processing Record 14 of Set 7 | olafsvik
# Processing Record 15 of Set 7 | chopan
# Processing Record 16 of Set 7 | kanadey
# Processing Record 17 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 7 | kununurra
# Processing Record 19 of Set 7 | talnakh
# Processing Record 20 of Set 7 | codrington
# Processing Record 21 of Set 7 | nyurba
# Processing Record 22 of Set 7 | eydhafushi
# Processing Record 23 of Set 7 | iqaluit
# Processing Record 24 of Set 7 | taos
# Processing Record 25 of Set 7 | xudat
# Processing Record 26 of Set 7 | santa maria del oro
# Processing Record 27 of Set 7 | sao joao da barra
# Processing Record 28 of Set 7 | puerto escondido
# Processing Record 29 of Set 7 | dauphin
# Processing Record 30 of Set 7 | auburndale
# Processing Record 31 of Set 7 | channel-port aux basques
# Processing Record 32 of Set 7 | klaksvik
# Processing Record 33 of Set 7 | siderno
# Processing Record 34 of Set 7 | cabedelo
# Processing Record 35 of Set 7 | kegayli
# City not found. Skipping...
# Processing Record 36 of Set 7 | crateus
# Processing Record 37 of Set 7 | grand gaube
# Processing Record 38 of Set 7 | kota kinabalu
# Processing Record 39 of Set 7 | saint george
# Processing Record 40 of Set 7 | cururupu
# Processing Record 41 of Set 7 | hengyang
# Processing Record 42 of Set 7 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 43 of Set 7 | tasiilaq
# Processing Record 44 of Set 7 | los llanos de aridane
# Processing Record 45 of Set 7 | shakhtinsk
# Processing Record 46 of Set 7 | ilo
# Processing Record 47 of Set 7 | santa luzia
# Processing Record 48 of Set 7 | ilulissat
# Processing Record 49 of Set 7 | sao felix do xingu
# Processing Record 50 of Set 7 | invermere
# Processing Record 1 of Set 8 | fengzhen
# Processing Record 2 of Set 8 | belaya gora
# Processing Record 3 of Set 8 | sao gabriel da cachoeira
# Processing Record 4 of Set 8 | haines junction
# Processing Record 5 of Set 8 | yar-sale
# Processing Record 6 of Set 8 | mahebourg
# Processing Record 7 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 8 | sokoni
# Processing Record 9 of Set 8 | hobyo
# Processing Record 10 of Set 8 | saldanha
# Processing Record 11 of Set 8 | quatre cocos
# Processing Record 12 of Set 8 | cayenne
# Processing Record 13 of Set 8 | pangody
# Processing Record 14 of Set 8 | izazi
# Processing Record 15 of Set 8 | rio grande
# Processing Record 16 of Set 8 | beyneu
# Processing Record 17 of Set 8 | te anau
# Processing Record 18 of Set 8 | vila velha
# Processing Record 19 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 8 | la ronge
# Processing Record 21 of Set 8 | henties bay
# Processing Record 22 of Set 8 | koumra
# Processing Record 23 of Set 8 | berlevag
# Processing Record 24 of Set 8 | presidencia roque saenz pena
# Processing Record 25 of Set 8 | teya
# Processing Record 26 of Set 8 | sarkand
# Processing Record 27 of Set 8 | anadyr
# Processing Record 28 of Set 8 | tamandare
# Processing Record 29 of Set 8 | biloela
# Processing Record 30 of Set 8 | north platte
# Processing Record 31 of Set 8 | moussoro
# Processing Record 32 of Set 8 | broome
# Processing Record 33 of Set 8 | silawit
# Processing Record 34 of Set 8 | canete
# Processing Record 35 of Set 8 | abalak
# Processing Record 36 of Set 8 | tomsk
# Processing Record 37 of Set 8 | souillac
# Processing Record 38 of Set 8 | maksi
# Processing Record 39 of Set 8 | necochea
# Processing Record 40 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 41 of Set 8 | tartki
# City not found. Skipping...
# Processing Record 42 of Set 8 | wilmington
# Processing Record 43 of Set 8 | sao filipe
# Processing Record 44 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 45 of Set 8 | bathsheba
# Processing Record 46 of Set 8 | muravlenko
# Processing Record 47 of Set 8 | beringovskiy
# Processing Record 48 of Set 8 | hualmay
# Processing Record 49 of Set 8 | phuket
# Processing Record 50 of Set 8 | cairns
# Processing Record 1 of Set 9 | bandarbeyla
# Processing Record 2 of Set 9 | aksarka
# Processing Record 3 of Set 9 | bestobe
# Processing Record 4 of Set 9 | kahului
# Processing Record 5 of Set 9 | port hardy
# Processing Record 6 of Set 9 | talipparamba
# Processing Record 7 of Set 9 | sierra vista
# Processing Record 8 of Set 9 | gniezno
# Processing Record 9 of Set 9 | treinta y tres
# Processing Record 10 of Set 9 | ust-maya
# Processing Record 11 of Set 9 | mehamn
# Processing Record 12 of Set 9 | kamenka
# Processing Record 13 of Set 9 | chernyshevskiy
# Processing Record 14 of Set 9 | suluktu
# Processing Record 15 of Set 9 | nabire
# Processing Record 16 of Set 9 | glendive
# Processing Record 17 of Set 9 | stoyba
# City not found. Skipping...
# Processing Record 18 of Set 9 | tilichiki
# Processing Record 19 of Set 9 | kavaratti
# Processing Record 20 of Set 9 | balkanabat
# Processing Record 21 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 23 of Set 9 | seoul
# Processing Record 24 of Set 9 | tonj
# Processing Record 25 of Set 9 | hirara
# Processing Record 26 of Set 9 | puerto ayacucho
# Processing Record 27 of Set 9 | selma
# Processing Record 28 of Set 9 | kudahuvadhoo
# Processing Record 29 of Set 9 | mabaruma
# Processing Record 30 of Set 9 | taoudenni
# Processing Record 31 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 32 of Set 9 | aykhal
# Processing Record 33 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 34 of Set 9 | severnyy
# Processing Record 35 of Set 9 | ekhabi
# Processing Record 36 of Set 9 | nanga eboko
# Processing Record 37 of Set 9 | ayna
# Processing Record 38 of Set 9 | champerico
# Processing Record 39 of Set 9 | sambava
# Processing Record 40 of Set 9 | romitan
# Processing Record 41 of Set 9 | sidi ali
# Processing Record 42 of Set 9 | mwene-ditu
# Processing Record 43 of Set 9 | ambunti
# Processing Record 44 of Set 9 | bokspits
# City not found. Skipping...
# Processing Record 45 of Set 9 | plettenberg bay
# Processing Record 46 of Set 9 | cordoba
# Processing Record 47 of Set 9 | umm kaddadah
# Processing Record 48 of Set 9 | toora-khem
# Processing Record 49 of Set 9 | katsuura
# Processing Record 50 of Set 9 | vostok
# Processing Record 1 of Set 10 | longyearbyen
# Processing Record 2 of Set 10 | fort nelson
# Processing Record 3 of Set 10 | hastings
# Processing Record 4 of Set 10 | kralendijk
# Processing Record 5 of Set 10 | antalaha
# Processing Record 6 of Set 10 | marystown
# Processing Record 7 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 8 of Set 10 | sawtell
# Processing Record 9 of Set 10 | langsa
# Processing Record 10 of Set 10 | lubango
# Processing Record 11 of Set 10 | manturovo
# Processing Record 12 of Set 10 | bien hoa
# Processing Record 13 of Set 10 | erzin
# Processing Record 14 of Set 10 | altar
# Processing Record 15 of Set 10 | itum-kale
# Processing Record 16 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 10 | hamilton
# Processing Record 18 of Set 10 | tateyama
# Processing Record 19 of Set 10 | musoma
# Processing Record 20 of Set 10 | pakxan
# Processing Record 21 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 22 of Set 10 | daeni
# Processing Record 23 of Set 10 | ziro
# Processing Record 24 of Set 10 | chibuto
# Processing Record 25 of Set 10 | sansai
# City not found. Skipping...
# Processing Record 26 of Set 10 | high prairie
# Processing Record 27 of Set 10 | manadhoo
# Processing Record 28 of Set 10 | manati
# Processing Record 29 of Set 10 | cape canaveral
# Processing Record 30 of Set 10 | bandar-e lengeh
# Processing Record 31 of Set 10 | yarkovo
# Processing Record 32 of Set 10 | alice springs
# Processing Record 33 of Set 10 | sapouy
# Processing Record 34 of Set 10 | upata
# Processing Record 35 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 36 of Set 10 | abu dhabi
# Processing Record 37 of Set 10 | santa isabel do rio negro
# Processing Record 38 of Set 10 | houlton
# Processing Record 39 of Set 10 | arman
# Processing Record 40 of Set 10 | cam ranh
# Processing Record 41 of Set 10 | novoselytsya
# Processing Record 42 of Set 10 | san luis
# Processing Record 43 of Set 10 | galgani
# City not found. Skipping...
# Processing Record 44 of Set 10 | staryy nadym
# Processing Record 45 of Set 10 | olinda
# Processing Record 46 of Set 10 | pascagoula
# Processing Record 47 of Set 10 | mandapeta
# Processing Record 48 of Set 10 | kushmurun
# Processing Record 49 of Set 10 | saint anthony
# Processing Record 50 of Set 10 | san patricio
# Processing Record 1 of Set 11 | zeya
# Processing Record 2 of Set 11 | ugoofaaru
# Processing Record 3 of Set 11 | brooks
# Processing Record 4 of Set 11 | honiara
# Processing Record 5 of Set 11 | makurdi
# Processing Record 6 of Set 11 | camacha
# Processing Record 7 of Set 11 | dhidhdhoo
# Processing Record 8 of Set 11 | medea
# Processing Record 9 of Set 11 | collie
# Processing Record 10 of Set 11 | pangoa
# Processing Record 11 of Set 11 | valparaiso
# Processing Record 12 of Set 11 | natulongan
# City not found. Skipping...
# Processing Record 13 of Set 11 | sadovoye
# Processing Record 14 of Set 11 | kirgiz-miyaki
# Processing Record 15 of Set 11 | pasni
# Processing Record 16 of Set 11 | hanyang
# Processing Record 17 of Set 11 | port shepstone
# Processing Record 18 of Set 11 | kamyshin
# Processing Record 19 of Set 11 | barcelos
# Processing Record 20 of Set 11 | imeni babushkina
# Processing Record 21 of Set 11 | obzor
# Processing Record 22 of Set 11 | skhisma
# Processing Record 23 of Set 11 | vao
# Processing Record 24 of Set 11 | santo antonio do ica
# Processing Record 25 of Set 11 | nakasongola
# Processing Record 26 of Set 11 | borba
# Processing Record 27 of Set 11 | kosh-agach
# Processing Record 28 of Set 11 | ulcinj
# Processing Record 29 of Set 11 | paredon
# Processing Record 30 of Set 11 | farafangana
# Processing Record 31 of Set 11 | nexo
# Processing Record 32 of Set 11 | coueron
# Processing Record 33 of Set 11 | aksu
# Processing Record 34 of Set 11 | porto torres
# Processing Record 35 of Set 11 | zyryanka
# Processing Record 36 of Set 11 | kieta
# Processing Record 37 of Set 11 | jaicos
# Processing Record 38 of Set 11 | montepuez
# Processing Record 39 of Set 11 | okha
# Processing Record 40 of Set 11 | doha
# Processing Record 41 of Set 11 | igbaras
# Processing Record 42 of Set 11 | clarksburg
# Processing Record 43 of Set 11 | copala
# Processing Record 44 of Set 11 | ilinskiy
# Processing Record 45 of Set 11 | myanaung
# Processing Record 46 of Set 11 | dongying
# Processing Record 47 of Set 11 | port hawkesbury
# Processing Record 48 of Set 11 | biak
# Processing Record 49 of Set 11 | muros
# Processing Record 50 of Set 11 | bereda
# Processing Record 1 of Set 12 | north bend
# Processing Record 2 of Set 12 | buin
# Processing Record 3 of Set 12 | sibulan
# Processing Record 4 of Set 12 | grindavik
# Processing Record 5 of Set 12 | razole
# Processing Record 6 of Set 12 | bud
# Processing Record 7 of Set 12 | khilok
# Processing Record 8 of Set 12 | rjukan
# Processing Record 9 of Set 12 | hervey bay
# Processing Record 10 of Set 12 | turan
# Processing Record 11 of Set 12 | callaguip
# Processing Record 12 of Set 12 | porto velho
# Processing Record 13 of Set 12 | lingao
# Processing Record 14 of Set 12 | shenjiamen
# Processing Record 15 of Set 12 | sur
# Processing Record 16 of Set 12 | maceio
# Processing Record 17 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 18 of Set 12 | nara
# Processing Record 19 of Set 12 | tynda
# Processing Record 20 of Set 12 | boma
# Processing Record 21 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 22 of Set 12 | babu
# Processing Record 23 of Set 12 | ossora
# Processing Record 24 of Set 12 | sorland
# Processing Record 25 of Set 12 | gat
# Processing Record 26 of Set 12 | nelson bay
# Processing Record 27 of Set 12 | sinnamary
# Processing Record 28 of Set 12 | candawaga
# City not found. Skipping...
# Processing Record 29 of Set 12 | montelibano
# Processing Record 30 of Set 12 | harper
# Processing Record 31 of Set 12 | ambulu
# Processing Record 32 of Set 12 | placido de castro
# Processing Record 33 of Set 12 | tromso
# Processing Record 34 of Set 12 | tecoanapa
# Processing Record 35 of Set 12 | tulun
# Processing Record 36 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 37 of Set 12 | karatau
# Processing Record 38 of Set 12 | alyangula
# Processing Record 39 of Set 12 | indramayu
# Processing Record 40 of Set 12 | mwinilunga
# Processing Record 41 of Set 12 | stephanskirchen
# Processing Record 42 of Set 12 | oktyabrskoye
# Processing Record 43 of Set 12 | mogok
# Processing Record 44 of Set 12 | mogadishu
# Processing Record 45 of Set 12 | tawnat
# City not found. Skipping...
# Processing Record 46 of Set 12 | blankenberge
# Processing Record 47 of Set 12 | ushibuka
# Processing Record 48 of Set 12 | saint-pierre
# Processing Record 49 of Set 12 | bambanglipuro
# Processing Record 50 of Set 12 | taltal
# Processing Record 1 of Set 13 | raudeberg
# Processing Record 2 of Set 13 | lorengau
# Processing Record 3 of Set 13 | fairbanks
# Processing Record 4 of Set 13 | yanji
# Processing Record 5 of Set 13 | xinzhi
# Processing Record 6 of Set 13 | wajima
# Processing Record 7 of Set 13 | ogbomosho
# Processing Record 8 of Set 13 | bontang
# Processing Record 9 of Set 13 | quelimane
# Processing Record 10 of Set 13 | bahir dar
# Processing Record 11 of Set 13 | cukai
# Processing Record 12 of Set 13 | bennington
# Processing Record 13 of Set 13 | tra vinh
# Processing Record 14 of Set 13 | krasnoslobodsk
# Processing Record 15 of Set 13 | avera
# Processing Record 16 of Set 13 | aleksinac
# Processing Record 17 of Set 13 | jiaojiang
# Processing Record 18 of Set 13 | mian channun
# Processing Record 19 of Set 13 | port keats
# Processing Record 20 of Set 13 | tabukiniberu
# City not found. Skipping...
# Processing Record 21 of Set 13 | adeje
# Processing Record 22 of Set 13 | cobija
# Processing Record 23 of Set 13 | talcahuano
# Processing Record 24 of Set 13 | winnipeg
# Processing Record 25 of Set 13 | tsaratanana
# Processing Record 26 of Set 13 | eureka
# Processing Record 27 of Set 13 | lieksa
# Processing Record 28 of Set 13 | bosaso
# Processing Record 29 of Set 13 | aras
# Processing Record 30 of Set 13 | temanggung
# Processing Record 31 of Set 13 | russell
# Processing Record 32 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 33 of Set 13 | carcassonne
# Processing Record 34 of Set 13 | kangaatsiaq
# Processing Record 35 of Set 13 | narsaq
# Processing Record 36 of Set 13 | atar
# Processing Record 37 of Set 13 | cap malheureux
# Processing Record 38 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 39 of Set 13 | itainopolis
# Processing Record 40 of Set 13 | boatlaname
# City not found. Skipping...
# Processing Record 41 of Set 13 | ternate
# Processing Record 42 of Set 13 | teguise
# Processing Record 43 of Set 13 | pemangkat
# Processing Record 44 of Set 13 | havre-saint-pierre
# Processing Record 45 of Set 13 | port moresby
# Processing Record 46 of Set 13 | abha
# Processing Record 47 of Set 13 | balingasay
# Processing Record 48 of Set 13 | thunder bay
# Processing Record 49 of Set 13 | ha tinh
# Processing Record 50 of Set 13 | banda aceh
# Processing Record 1 of Set 14 | mbour
# Processing Record 2 of Set 14 | vyartsilya
# Processing Record 3 of Set 14 | pontes e lacerda
# Processing Record 4 of Set 14 | brawley
# Processing Record 5 of Set 14 | joshimath
# Processing Record 6 of Set 14 | hailey
# Processing Record 7 of Set 14 | abong mbang
# Processing Record 8 of Set 14 | qui nhon
# Processing Record 9 of Set 14 | jacareacanga
# Processing Record 10 of Set 14 | oktyabrskiy
# Processing Record 11 of Set 14 | yenagoa
# Processing Record 12 of Set 14 | talmenka
# Processing Record 13 of Set 14 | peace river
# Processing Record 14 of Set 14 | cherskiy
# Processing Record 15 of Set 14 | jeremie
# Processing Record 16 of Set 14 | raglan
# Processing Record 17 of Set 14 | honghu
# Processing Record 18 of Set 14 | sola
# Processing Record 19 of Set 14 | verkhnevilyuysk
# Processing Record 20 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 21 of Set 14 | burica
# City not found. Skipping...
# Processing Record 22 of Set 14 | choya
# Processing Record 23 of Set 14 | harer
# Processing Record 24 of Set 14 | senanga
# Processing Record 25 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 26 of Set 14 | basco
# Processing Record 27 of Set 14 | birjand
# Processing Record 28 of Set 14 | kusye-aleksandrovskiy
# City not found. Skipping...
# Processing Record 29 of Set 14 | porto belo
# Processing Record 30 of Set 14 | negombo
# Processing Record 31 of Set 14 | port macquarie
# Processing Record 32 of Set 14 | vila
# Processing Record 33 of Set 14 | tual
# Processing Record 34 of Set 14 | port augusta
# Processing Record 35 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 36 of Set 14 | basna
# Processing Record 37 of Set 14 | redmond
# Processing Record 38 of Set 14 | concordia
# Processing Record 39 of Set 14 | khandyga
# Processing Record 40 of Set 14 | novaya igirma
# Processing Record 41 of Set 14 | phillipsburg
# Processing Record 42 of Set 14 | aleksandrov gay
# Processing Record 43 of Set 14 | japura
# Processing Record 44 of Set 14 | sechura
# Processing Record 45 of Set 14 | saint-augustin
# Processing Record 46 of Set 14 | boueni
# Processing Record 47 of Set 14 | bayir
# Processing Record 48 of Set 14 | hun
# Processing Record 49 of Set 14 | huarmey
# Processing Record 50 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 15 | prince rupert
# Processing Record 2 of Set 15 | payo
# Processing Record 3 of Set 15 | taksimo
# Processing Record 4 of Set 15 | kathu
# Processing Record 5 of Set 15 | mirina
# City not found. Skipping...
# Processing Record 6 of Set 15 | porto novo
# Processing Record 7 of Set 15 | pegnitz
# Processing Record 8 of Set 15 | ust-barguzin
# Processing Record 9 of Set 15 | lyambir
# Processing Record 10 of Set 15 | susangerd
# Processing Record 11 of Set 15 | weligama
# Processing Record 12 of Set 15 | rioblanco
# Processing Record 13 of Set 15 | kulhudhuffushi
# Processing Record 14 of Set 15 | ornes
# Processing Record 15 of Set 15 | maniitsoq
# Processing Record 16 of Set 15 | charters towers
# Processing Record 17 of Set 15 | fort morgan
# Processing Record 18 of Set 15 | dilla
# Processing Record 19 of Set 15 | valle hermoso
# Processing Record 20 of Set 15 | darnah
# Processing Record 21 of Set 15 | yakeshi
# Processing Record 22 of Set 15 | baykit
# Processing Record 23 of Set 15 | kalmunai
# Processing Record 24 of Set 15 | marsa matruh
# Processing Record 25 of Set 15 | zhigansk
# Processing Record 26 of Set 15 | gorontalo
# Processing Record 27 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 28 of Set 15 | takoradi
# Processing Record 29 of Set 15 | mmabatho
# Processing Record 30 of Set 15 | pozoblanco
# Processing Record 31 of Set 15 | mayo
# Processing Record 32 of Set 15 | aswan
# Processing Record 33 of Set 15 | kiunga
# Processing Record 34 of Set 15 | tautira
# Processing Record 35 of Set 15 | laela
# Processing Record 36 of Set 15 | emerald
# Processing Record 37 of Set 15 | bima
# Processing Record 38 of Set 15 | ilam
# Processing Record 39 of Set 15 | bukama
# Processing Record 40 of Set 15 | broken hill
# Processing Record 41 of Set 15 | santa cruz
# Processing Record 42 of Set 15 | plouzane
# Processing Record 43 of Set 15 | dunedin
# Processing Record 44 of Set 15 | ponta delgada
# Processing Record 45 of Set 15 | fenoarivo
# Processing Record 46 of Set 15 | menongue
# Processing Record 47 of Set 15 | urumqi
# Processing Record 48 of Set 15 | synya
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Padang      ID  -0.9492  100.3543     79.09        79          96
# 1         Ushuaia      AR -54.8000  -68.3000     46.06        66          20
# 2      Port Blair      IN  11.6667   92.7500     82.44        78          20
# 3         Rikitea      PF -23.1203 -134.9692     78.96        74          35
# 4  Port Elizabeth      ZA -33.9180   25.5701     66.09        81         100
# 5           Kapaa      US  22.0752 -159.3190     73.72        84         100
# 6          Laguna      US  38.4210 -121.4238     63.05        36           0
# 7      Saint-Paul      RE -21.0096   55.2707     80.71        83          30
# 8   San Cristobal      VE   7.7669  -72.2250     77.18        35          87
# 9        Cidreira      BR -30.1811  -50.2056     72.57        79          84
#
#    Wind Speed Current Description
# 0        3.00     overcast clouds
# 1        0.00          few clouds
# 2        2.30                mist
# 3       17.98    scattered clouds
# 4       16.11     overcast clouds
# 5       17.27     overcast clouds
# 6       21.85           clear sky
# 7        1.77          light rain
# 8        9.44     overcast clouds
# 9        9.35       broken clouds

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder
#Weather_DF_Output.to_csv("WeatherPy_Database.csv")
Weather_DF_Output = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(Weather_DF_Output, index_label="City_ID")
